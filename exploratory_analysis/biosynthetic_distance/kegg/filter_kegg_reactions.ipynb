# %%
import pandas as pd


kegg = pd.read_csv("kegg_reactions.csv")

# %%
kegg = kegg[~kegg["pathway_id"].isin(["map00010", "map00020", "map00030", "map00520", "map00500", "map00230", "map00220"])]

# %%
kegg.to_csv("filtered_kegg_reactions.csv", index=False)
